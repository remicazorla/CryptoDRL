# %%
pip install python-binance

# %%
import pandas as pd
from binance.client import Client
from tqdm import tqdm
client = Client()

# %%
import sys
sys.path.append('..')
from lib.download import *
from lib.download import update_data_features
update_data_features(symbols=get_symbol())
# Out:
#  	###   10 / 616  |  0h:0m:37s  | 0h:37m:26s  ###
#
#
#  	###   20 / 616  |  0h:1m:4s  | 0h:32m:1s  ###
#
#
#  	###   30 / 616  |  0h:1m:29s  | 0h:29m:13s  ###
#
#
#  	###   40 / 616  |  0h:1m:56s  | 0h:28m:1s  ###
#
#
#  	###   50 / 616  |  0h:2m:13s  | 0h:25m:13s  ###
#
#
#  	###   60 / 616  |  0h:2m:38s  | 0h:24m:29s  ###
#
#
#  	###   70 / 616  |  0h:3m:9s  | 0h:24m:35s  ###
#
#
#  	###   80 / 616  |  0h:3m:32s  | 0h:23m:43s  ###
#
#
#  	###   90 / 616  |  0h:3m:58s  | 0h:23m:16s  ###
#
#
#  	###   100 / 616  |  0h:4m:23s  | 0h:22m:41s  ###
#
#
#  	###   110 / 616  |  0h:4m:40s  | 0h:21m:32s  ###
#
#
#  	###   120 / 616  |  0h:5m:16s  | 0h:21m:47s  ###
#
#
#  	###   130 / 616  |  0h:5m:40s  | 0h:21m:14s  ###
#
#
#  	###   140 / 616  |  0h:6m:13s  | 0h:21m:10s  ###
#
#
#  	###   150 / 616  |  0h:6m:30s  | 0h:20m:11s  ###
#
#
#  	###   160 / 616  |  0h:6m:58s  | 0h:19m:52s  ###
#
#
#  	###   170 / 616  |  0h:7m:22s  | 0h:19m:21s  ###
#
#
#  	###   180 / 616  |  0h:7m:55s  | 0h:19m:11s  ###
#
#
#  	###   190 / 616  |  0h:8m:20s  | 0h:18m:42s  ###
#
#
#  	###   200 / 616  |  0h:8m:43s  | 0h:18m:8s  ###
#
#
#  	###   210 / 616  |  0h:9m:16s  | 0h:17m:56s  ###
#
#
#  	###   220 / 616  |  0h:9m:38s  | 0h:17m:21s  ###
#
#
#  	###   230 / 616  |  0h:10m:5s  | 0h:16m:55s  ###
#
#
#  	###   240 / 616  |  0h:10m:28s  | 0h:16m:24s  ###
#
#
#  	###   250 / 616  |  0h:10m:49s  | 0h:15m:51s  ###
#
#
#  	###   260 / 616  |  0h:11m:16s  | 0h:15m:26s  ###
#
#
#  	###   270 / 616  |  0h:11m:43s  | 0h:15m:1s  ###
#
#
#  	###   280 / 616  |  0h:12m:9s  | 0h:14m:35s  ###
#
#
#  	###   290 / 616  |  0h:12m:38s  | 0h:14m:12s  ###
#
#
#  	###   300 / 616  |  0h:12m:55s  | 0h:13m:36s  ###
#
#
#  	###   310 / 616  |  0h:13m:5s  | 0h:12m:55s  ###
#
#
#  	###   320 / 616  |  0h:13m:15s  | 0h:12m:15s  ###
#
#
#  	###   330 / 616  |  0h:13m:24s  | 0h:11m:36s  ###
#
#
#  	###   340 / 616  |  0h:13m:36s  | 0h:11m:3s  ###
#
#
#  	###   350 / 616  |  0h:13m:44s  | 0h:10m:26s  ###
#
#
#  	###   360 / 616  |  0h:13m:52s  | 0h:9m:52s  ###
#
#
#  	###   370 / 616  |  0h:13m:59s  | 0h:9m:18s  ###
#
#
#  	###   380 / 616  |  0h:14m:9s  | 0h:8m:47s  ###
#
#
#  	###   390 / 616  |  0h:14m:20s  | 0h:8m:18s  ###
#
#
#  	###   400 / 616  |  0h:14m:23s  | 0h:7m:46s  ###
#
#
#  	###   410 / 616  |  0h:14m:34s  | 0h:7m:19s  ###
#
#
#  	###   420 / 616  |  0h:14m:40s  | 0h:6m:51s  ###
#
#
#  	###   430 / 616  |  0h:14m:45s  | 0h:6m:23s  ###
#
#
#  	###   440 / 616  |  0h:14m:55s  | 0h:5m:58s  ###
#
#
#  	###   450 / 616  |  0h:15m:6s  | 0h:5m:34s  ###
#
#
#  	###   460 / 616  |  0h:15m:11s  | 0h:5m:8s  ###
#
#
#  	###   470 / 616  |  0h:15m:22s  | 0h:4m:46s  ###
#
#
#  	###   480 / 616  |  0h:15m:31s  | 0h:4m:23s  ###
#
#
#  	###   490 / 616  |  0h:15m:44s  | 0h:4m:2s  ###
#
#
#  	###   500 / 616  |  0h:15m:48s  | 0h:3m:40s  ###
#
#
#  	###   510 / 616  |  0h:15m:56s  | 0h:3m:18s  ###
#
#
#  	###   520 / 616  |  0h:16m:6s  | 0h:2m:58s  ###
#
#
#  	###   530 / 616  |  0h:16m:15s  | 0h:2m:38s  ###
#
#
#  	###   540 / 616  |  0h:16m:48s  | 0h:2m:21s  ###
#
#
#  	###   550 / 616  |  0h:17m:0s  | 0h:2m:2s  ###
#
#
#  	###   560 / 616  |  0h:17m:4s  | 0h:1m:42s  ###
#
#
#  	###   570 / 616  |  0h:17m:11s  | 0h:1m:23s  ###
#
#
#  	###   580 / 616  |  0h:17m:20s  | 0h:1m:4s  ###
#
#
#  	###   590 / 616  |  0h:17m:30s  | 0h:0m:46s  ###
#
#
#  	###   600 / 616  |  0h:17m:34s  | 0h:0m:28s  ###
#
#
#  	###   610 / 616  |  0h:17m:48s  | 0h:0m:10s  ###

# %%
def download_symbol_data(symbol, start = "01 january 2018", interval = Client.KLINE_INTERVAL_1HOUR):
    klinesT = client.get_historical_klines(symbol, interval, start)
    df = pd.DataFrame(klinesT, columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_av', 'trades', 'tb_base_av', 'tb_quote_av', 'ignore'])
    df = df.set_index(df['timestamp'])
    df.index = pd.to_datetime(df.index, unit='ms')
    del df['timestamp']
    
    return df

def save_data_pickle(df, symbol):
    df.to_pickle(f'usdt_data/{symbol}.pickle')

def save_data_features_pickle(df, symbol):
    df.to_pickle(f'usdt_data_features/{symbol}.pickle')
    
def download_symbols_data(symbols):
    for symbol in tqdm(symbols):
        try:
            download_symbol_data(symbol)
        except:
            print(':)')

def update_data_symbol(symbol):
    lastindex = pd.read_pickle(f'usdt_data/{symbol}.pickle').index[-1]
    lastdata = download_symbol_data(symbol, start = str(lastindex))
    current_data = pd.read_pickle(f'usdt_data/{symbol}.pickle')
    newdf = pd.concat([current_data,lastdata],axis=0)
    save_data_pickle(newdf, symbol)
    
    return newdf

def update_data(symbols):
    for symbol in symbols:
            update_data_symbol(symbol)

# %%
update_data(usdt_symbols)
